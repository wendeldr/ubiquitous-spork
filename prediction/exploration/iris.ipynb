# %%
from sklearn import datasets
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
df = datasets.load_breast_cancer()
df.data.shape
# Out:
# (569, 30)

# %%
df['data'].shape
# Out:
# (569, 30)

# %%
METRICS = [
    keras.metrics.BinaryCrossentropy(name='cross entropy'),  # same as model's loss
    keras.metrics.MeanSquaredError(name='Brier score'),
    keras.metrics.TruePositives(name='tp'),
    keras.metrics.FalsePositives(name='fp'),
    keras.metrics.TrueNegatives(name='tn'),
    keras.metrics.FalseNegatives(name='fn'),
    keras.metrics.BinaryAccuracy(name='accuracy'),
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall'),
    keras.metrics.AUC(name='auc'),
    keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]


def early_stopping():
 return tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    verbose=1,
    patience=5,
    mode='min',
    restore_best_weights=True)

# %%
data = np.concatenate([df['data'], df['target'].reshape(-1, 1)], axis=1)

# %%
# Use a utility from sklearn to split and shuffle your dataset.
train_df, test_df = train_test_split(data, test_size=0.2)
train_df, val_df = train_test_split(train_df, test_size=0.2)

# Form np arrays of labels and features.
train_labels = np.array(train_df[:,-1]).reshape(-1, 1)
bool_train_labels = train_labels[:, 0] != 0
val_labels = np.array(val_df[:,-1]).reshape(-1, 1)
test_labels = np.array(test_df[:,-1]).reshape(-1, 1)

train_features = np.array(train_df[:,:-1])
val_features = np.array(val_df[:,:-1])
test_features = np.array(test_df[:,:-1])

# %%
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)

val_features = scaler.transform(val_features)
test_features = scaler.transform(test_features)

# train_features = np.clip(train_features, -5, 5)
# val_features = np.clip(val_features, -5, 5)
# test_features = np.clip(test_features, -5, 5)

# %%
# output_bias = keras.initializers.Constant(initial_bias)
N_value = train_features.shape[1]
inputs = keras.Input(shape=(N_value,))

# Reshape to (batch, N, 1) to treat each feature as a token.
x = keras.layers.Reshape((N_value, 1))(inputs)

# Self-attention block:
# Using one head with key_dim=1 so that the attention scores have shape (batch, 1, N, N)
attn_layer = keras.layers.MultiHeadAttention(num_heads=4,key_dim=15)
# We set return_attention_scores=True to obtain the attention matrix.
output_tensor, attn_scores = attn_layer(x, x, return_attention_scores=True, )
# Remove the head dimension so attn_scores becomes (batch, N, N)
# attn_scores = keras.layers.Lambda(lambda t: tf.squeeze(t, axis=1))(attn_scores)

# Apply layer normalization to the attention matrix.
x = keras.layers.LayerNormalization()(output_tensor)

# # Option 1: Global pooling over the token dimension to reduce (N, N) to a vector of length N.
# x = keras.layers.GlobalAveragePooling1D()(x)
x = keras.layers.Flatten()(x)

# # MLP block:
# Dense layers with sizes: 4*N, 2*N, N and output layer with 2 units.
x = keras.layers.Dense(4 * N_value, activation='relu')(x)
x = keras.layers.Dense(2 * N_value, activation='relu')(x)
x = keras.layers.Dense(N_value, activation='relu')(x)
outputs = keras.layers.Dense(1, activation='sigmoid')(x)

model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.BinaryCrossentropy(),
    metrics=METRICS
)

# %%
EPOCHS = 200
BATCH_SIZE = 32

history = model.fit(
    train_features,
    train_labels,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(val_features, val_labels),
    verbose=1,
    callbacks=[early_stopping()])
# Out:
# Epoch 1/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 357ms/step - Brier score: 0.2498 - accuracy: 0.5765 - auc: 0.5000 - cross entropy: 0.6928 - fn: 18.0000 - fp: 70.3077 - loss: 0.6928 - prc: 0.6072 - precision: 0.5739 - recall: 0.7659 - tn: 14.0000 - tp: 116.1538 - val_Brier score: 0.2495 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6922 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6922 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2492 - accuracy: 0.6222 - auc: 0.5109 - cross entropy: 0.6916 - fn: 0.0000e+00 - fp: 82.1538 - loss: 0.6916 - prc: 0.6281 - precision: 0.6222 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.3077 - val_Brier score: 0.2491 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6913 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6913 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2487 - accuracy: 0.6249 - auc: 0.5000 - cross entropy: 0.6905 - fn: 0.0000e+00 - fp: 83.6154 - loss: 0.6905 - prc: 0.6249 - precision: 0.6249 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.8462 - val_Brier score: 0.2487 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6906 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6906 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2481 - accuracy: 0.6314 - auc: 0.4886 - cross entropy: 0.6893 - fn: 0.0000e+00 - fp: 82.8462 - loss: 0.6893 - prc: 0.6243 - precision: 0.6314 - recall: 1.0000 - tn: 0.0000e+00 - tp: 135.6154 - val_Brier score: 0.2483 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6898 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6898 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2481 - accuracy: 0.5980 - auc: 0.5000 - cross entropy: 0.6894 - fn: 0.0000e+00 - fp: 83.6923 - loss: 0.6894 - prc: 0.5980 - precision: 0.5980 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.7692 - val_Brier score: 0.2479 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6890 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6890 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2472 - accuracy: 0.6202 - auc: 0.5011 - cross entropy: 0.6876 - fn: 0.0000e+00 - fp: 84.2308 - loss: 0.6876 - prc: 0.6217 - precision: 0.6202 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.2308 - val_Brier score: 0.2476 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6883 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6883 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2474 - accuracy: 0.5952 - auc: 0.5000 - cross entropy: 0.6880 - fn: 0.0000e+00 - fp: 86.6923 - loss: 0.6880 - prc: 0.5952 - precision: 0.5952 - recall: 1.0000 - tn: 0.0000e+00 - tp: 131.7692 - val_Brier score: 0.2473 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6877 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6877 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2472 - accuracy: 0.5930 - auc: 0.4984 - cross entropy: 0.6875 - fn: 0.0000e+00 - fp: 86.6154 - loss: 0.6875 - prc: 0.5911 - precision: 0.5930 - recall: 1.0000 - tn: 0.0000e+00 - tp: 131.8462 - val_Brier score: 0.2469 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6870 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6870 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2461 - accuracy: 0.6107 - auc: 0.5000 - cross entropy: 0.6854 - fn: 0.0000e+00 - fp: 84.1538 - loss: 0.6854 - prc: 0.6107 - precision: 0.6107 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.3077 - val_Brier score: 0.2466 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6863 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6863 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2465 - accuracy: 0.5922 - auc: 0.5000 - cross entropy: 0.6861 - fn: 0.0000e+00 - fp: 85.7692 - loss: 0.6861 - prc: 0.5922 - precision: 0.5922 - recall: 1.0000 - tn: 0.0000e+00 - tp: 132.6923 - val_Brier score: 0.2463 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6857 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6857 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2436 - accuracy: 0.6500 - auc: 0.5000 - cross entropy: 0.6804 - fn: 0.0000e+00 - fp: 80.8462 - loss: 0.6804 - prc: 0.6500 - precision: 0.6500 - recall: 1.0000 - tn: 0.0000e+00 - tp: 137.6154 - val_Brier score: 0.2460 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6852 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6852 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2460 - accuracy: 0.5928 - auc: 0.5000 - cross entropy: 0.6851 - fn: 0.0000e+00 - fp: 86.6923 - loss: 0.6851 - prc: 0.5928 - precision: 0.5928 - recall: 1.0000 - tn: 0.0000e+00 - tp: 131.7692 - val_Brier score: 0.2458 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6847 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6847 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2438 - accuracy: 0.6295 - auc: 0.4818 - cross entropy: 0.6807 - fn: 0.0000e+00 - fp: 80.2308 - loss: 0.6807 - prc: 0.6147 - precision: 0.6295 - recall: 1.0000 - tn: 0.0000e+00 - tp: 138.2308 - val_Brier score: 0.2455 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6842 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6842 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2443 - accuracy: 0.6135 - auc: 0.5000 - cross entropy: 0.6817 - fn: 0.0000e+00 - fp: 84.6154 - loss: 0.6817 - prc: 0.6135 - precision: 0.6135 - recall: 1.0000 - tn: 0.0000e+00 - tp: 133.8462 - val_Brier score: 0.2453 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6837 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6837 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2445 - accuracy: 0.6053 - auc: 0.5000 - cross entropy: 0.6821 - fn: 0.0000e+00 - fp: 84.7692 - loss: 0.6821 - prc: 0.6053 - precision: 0.6053 - recall: 1.0000 - tn: 0.0000e+00 - tp: 133.6923 - val_Brier score: 0.2450 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6832 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6832 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2449 - accuracy: 0.5942 - auc: 0.5133 - cross entropy: 0.6829 - fn: 0.0000e+00 - fp: 85.6923 - loss: 0.6829 - prc: 0.6022 - precision: 0.5942 - recall: 1.0000 - tn: 0.0000e+00 - tp: 132.7692 - val_Brier score: 0.2448 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6827 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6827 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2431 - accuracy: 0.6170 - auc: 0.5000 - cross entropy: 0.6794 - fn: 0.0000e+00 - fp: 83.0000 - loss: 0.6794 - prc: 0.6170 - precision: 0.6170 - recall: 1.0000 - tn: 0.0000e+00 - tp: 135.4615 - val_Brier score: 0.2446 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6823 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6823 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2435 - accuracy: 0.6073 - auc: 0.5000 - cross entropy: 0.6801 - fn: 0.0000e+00 - fp: 84.9231 - loss: 0.6801 - prc: 0.6073 - precision: 0.6073 - recall: 1.0000 - tn: 0.0000e+00 - tp: 133.5385 - val_Brier score: 0.2444 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6819 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6819 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2407 - accuracy: 0.6418 - auc: 0.5000 - cross entropy: 0.6744 - fn: 0.0000e+00 - fp: 81.2308 - loss: 0.6744 - prc: 0.6418 - precision: 0.6418 - recall: 1.0000 - tn: 0.0000e+00 - tp: 137.2308 - val_Brier score: 0.2442 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6814 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6814 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2431 - accuracy: 0.6056 - auc: 0.5000 - cross entropy: 0.6794 - fn: 0.0000e+00 - fp: 85.0000 - loss: 0.6794 - prc: 0.6056 - precision: 0.6056 - recall: 1.0000 - tn: 0.0000e+00 - tp: 133.4615 - val_Brier score: 0.2440 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6811 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6811 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2381 - accuracy: 0.6633 - auc: 0.5010 - cross entropy: 0.6694 - fn: 0.0000e+00 - fp: 80.0000 - loss: 0.6694 - prc: 0.6639 - precision: 0.6633 - recall: 1.0000 - tn: 0.0000e+00 - tp: 138.4615 - val_Brier score: 0.2438 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6807 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6807 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2428 - accuracy: 0.6042 - auc: 0.5000 - cross entropy: 0.6787 - fn: 0.0000e+00 - fp: 85.6923 - loss: 0.6787 - prc: 0.6042 - precision: 0.6042 - recall: 1.0000 - tn: 0.0000e+00 - tp: 132.7692 - val_Brier score: 0.2436 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6803 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6803 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2422 - accuracy: 0.6082 - auc: 0.5000 - cross entropy: 0.6776 - fn: 0.0000e+00 - fp: 86.4615 - loss: 0.6776 - prc: 0.6082 - precision: 0.6082 - recall: 1.0000 - tn: 0.0000e+00 - tp: 132.0000 - val_Brier score: 0.2435 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6800 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6800 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2384 - accuracy: 0.6469 - auc: 0.4955 - cross entropy: 0.6699 - fn: 0.0000e+00 - fp: 79.8462 - loss: 0.6699 - prc: 0.6441 - precision: 0.6469 - recall: 1.0000 - tn: 0.0000e+00 - tp: 138.6154 - val_Brier score: 0.2433 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6797 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6797 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2392 - accuracy: 0.6348 - auc: 0.5000 - cross entropy: 0.6715 - fn: 0.0000e+00 - fp: 81.1538 - loss: 0.6715 - prc: 0.6348 - precision: 0.6348 - recall: 1.0000 - tn: 0.0000e+00 - tp: 137.3077 - val_Brier score: 0.2431 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6794 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6794 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2412 - accuracy: 0.6119 - auc: 0.5000 - cross entropy: 0.6756 - fn: 0.0000e+00 - fp: 84.5385 - loss: 0.6756 - prc: 0.6119 - precision: 0.6119 - recall: 1.0000 - tn: 0.0000e+00 - tp: 133.9231 - val_Brier score: 0.2430 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6791 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6791 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2388 - accuracy: 0.6334 - auc: 0.4949 - cross entropy: 0.6707 - fn: 0.0000e+00 - fp: 82.4615 - loss: 0.6707 - prc: 0.6289 - precision: 0.6334 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.0000 - val_Brier score: 0.2429 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6789 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6789 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2416 - accuracy: 0.6046 - auc: 0.5000 - cross entropy: 0.6764 - fn: 0.0000e+00 - fp: 85.9231 - loss: 0.6764 - prc: 0.6046 - precision: 0.6046 - recall: 1.0000 - tn: 0.0000e+00 - tp: 132.5385 - val_Brier score: 0.2428 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6786 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6786 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2418 - accuracy: 0.6015 - auc: 0.5000 - cross entropy: 0.6768 - fn: 0.0000e+00 - fp: 87.5385 - loss: 0.6768 - prc: 0.6015 - precision: 0.6015 - recall: 1.0000 - tn: 0.0000e+00 - tp: 130.9231 - val_Brier score: 0.2427 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6784 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6784 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2374 - accuracy: 0.6399 - auc: 0.5026 - cross entropy: 0.6678 - fn: 0.0000e+00 - fp: 80.0769 - loss: 0.6678 - prc: 0.6430 - precision: 0.6399 - recall: 1.0000 - tn: 0.0000e+00 - tp: 138.3846 - val_Brier score: 0.2425 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6781 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6781 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2378 - accuracy: 0.6341 - auc: 0.5000 - cross entropy: 0.6686 - fn: 0.0000e+00 - fp: 82.0769 - loss: 0.6686 - prc: 0.6341 - precision: 0.6341 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.3846 - val_Brier score: 0.2424 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6779 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6779 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2363 - accuracy: 0.6450 - auc: 0.5000 - cross entropy: 0.6655 - fn: 0.0000e+00 - fp: 79.6923 - loss: 0.6655 - prc: 0.6450 - precision: 0.6450 - recall: 1.0000 - tn: 0.0000e+00 - tp: 138.7692 - val_Brier score: 0.2423 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6777 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6777 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2387 - accuracy: 0.6228 - auc: 0.5000 - cross entropy: 0.6705 - fn: 0.0000e+00 - fp: 82.7692 - loss: 0.6705 - prc: 0.6228 - precision: 0.6228 - recall: 1.0000 - tn: 0.0000e+00 - tp: 135.6923 - val_Brier score: 0.2422 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6776 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6776 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 34/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2378 - accuracy: 0.6288 - auc: 0.4735 - cross entropy: 0.6686 - fn: 0.0000e+00 - fp: 81.7692 - loss: 0.6686 - prc: 0.6116 - precision: 0.6288 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.6923 - val_Brier score: 0.2422 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6774 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6774 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 35/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2358 - accuracy: 0.6426 - auc: 0.5000 - cross entropy: 0.6647 - fn: 0.0000e+00 - fp: 80.6154 - loss: 0.6647 - prc: 0.6426 - precision: 0.6426 - recall: 1.0000 - tn: 0.0000e+00 - tp: 137.8462 - val_Brier score: 0.2421 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6772 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6772 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 36/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2389 - accuracy: 0.6176 - auc: 0.5000 - cross entropy: 0.6708 - fn: 0.0000e+00 - fp: 84.0000 - loss: 0.6708 - prc: 0.6176 - precision: 0.6176 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.4615 - val_Brier score: 0.2420 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6771 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6771 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 37/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2403 - accuracy: 0.6058 - auc: 0.5000 - cross entropy: 0.6737 - fn: 0.0000e+00 - fp: 83.6923 - loss: 0.6737 - prc: 0.6058 - precision: 0.6058 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.7692 - val_Brier score: 0.2419 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6769 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6769 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 38/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2366 - accuracy: 0.6326 - auc: 0.4672 - cross entropy: 0.6662 - fn: 0.0000e+00 - fp: 82.1538 - loss: 0.6662 - prc: 0.6152 - precision: 0.6326 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.3077 - val_Brier score: 0.2419 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6768 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6768 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 39/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2360 - accuracy: 0.6359 - auc: 0.5000 - cross entropy: 0.6649 - fn: 0.0000e+00 - fp: 81.9231 - loss: 0.6649 - prc: 0.6359 - precision: 0.6359 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.5385 - val_Brier score: 0.2418 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6767 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6767 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 40/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2427 - accuracy: 0.5866 - auc: 0.5000 - cross entropy: 0.6785 - fn: 0.0000e+00 - fp: 86.8462 - loss: 0.6785 - prc: 0.5866 - precision: 0.5866 - recall: 1.0000 - tn: 0.0000e+00 - tp: 131.6154 - val_Brier score: 0.2418 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6766 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6766 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 41/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2361 - accuracy: 0.6325 - auc: 0.5000 - cross entropy: 0.6653 - fn: 0.0000e+00 - fp: 82.3077 - loss: 0.6653 - prc: 0.6325 - precision: 0.6325 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.1538 - val_Brier score: 0.2417 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6765 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6765 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 42/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2344 - accuracy: 0.6434 - auc: 0.4756 - cross entropy: 0.6618 - fn: 0.0000e+00 - fp: 81.1538 - loss: 0.6618 - prc: 0.6309 - precision: 0.6434 - recall: 1.0000 - tn: 0.0000e+00 - tp: 137.3077 - val_Brier score: 0.2417 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6764 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6764 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 43/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2390 - accuracy: 0.6110 - auc: 0.5000 - cross entropy: 0.6711 - fn: 0.0000e+00 - fp: 84.0769 - loss: 0.6711 - prc: 0.6110 - precision: 0.6110 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.3846 - val_Brier score: 0.2416 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6763 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6763 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 44/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2374 - accuracy: 0.6215 - auc: 0.5000 - cross entropy: 0.6678 - fn: 0.0000e+00 - fp: 83.3846 - loss: 0.6678 - prc: 0.6215 - precision: 0.6215 - recall: 1.0000 - tn: 0.0000e+00 - tp: 135.0769 - val_Brier score: 0.2416 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6762 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6762 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 45/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2367 - accuracy: 0.6257 - auc: 0.5000 - cross entropy: 0.6663 - fn: 0.0000e+00 - fp: 83.6154 - loss: 0.6663 - prc: 0.6257 - precision: 0.6257 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.8462 - val_Brier score: 0.2415 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6761 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6761 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 46/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2396 - accuracy: 0.6059 - auc: 0.5004 - cross entropy: 0.6722 - fn: 0.0000e+00 - fp: 85.6154 - loss: 0.6722 - prc: 0.6063 - precision: 0.6059 - recall: 1.0000 - tn: 0.0000e+00 - tp: 132.8462 - val_Brier score: 0.2415 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6761 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6761 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 47/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2340 - accuracy: 0.6413 - auc: 0.5000 - cross entropy: 0.6609 - fn: 0.0000e+00 - fp: 81.3077 - loss: 0.6609 - prc: 0.6413 - precision: 0.6413 - recall: 1.0000 - tn: 0.0000e+00 - tp: 137.1538 - val_Brier score: 0.2415 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6760 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6760 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 48/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2345 - accuracy: 0.6373 - auc: 0.5000 - cross entropy: 0.6619 - fn: 0.0000e+00 - fp: 82.6154 - loss: 0.6619 - prc: 0.6373 - precision: 0.6373 - recall: 1.0000 - tn: 0.0000e+00 - tp: 135.8462 - val_Brier score: 0.2414 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6759 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6759 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 49/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2411 - accuracy: 0.5955 - auc: 0.5000 - cross entropy: 0.6752 - fn: 0.0000e+00 - fp: 84.5385 - loss: 0.6752 - prc: 0.5955 - precision: 0.5955 - recall: 1.0000 - tn: 0.0000e+00 - tp: 133.9231 - val_Brier score: 0.2414 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6759 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6759 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 50/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2301 - accuracy: 0.6629 - auc: 0.5000 - cross entropy: 0.6530 - fn: 0.0000e+00 - fp: 79.6923 - loss: 0.6530 - prc: 0.6629 - precision: 0.6629 - recall: 1.0000 - tn: 0.0000e+00 - tp: 138.7692 - val_Brier score: 0.2414 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6758 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6758 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 51/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2336 - accuracy: 0.6405 - auc: 0.4781 - cross entropy: 0.6601 - fn: 0.0000e+00 - fp: 80.6923 - loss: 0.6601 - prc: 0.6269 - precision: 0.6405 - recall: 1.0000 - tn: 0.0000e+00 - tp: 137.7692 - val_Brier score: 0.2414 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6758 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6758 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 52/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2334 - accuracy: 0.6412 - auc: 0.5000 - cross entropy: 0.6596 - fn: 0.0000e+00 - fp: 81.2308 - loss: 0.6596 - prc: 0.6412 - precision: 0.6412 - recall: 1.0000 - tn: 0.0000e+00 - tp: 137.2308 - val_Brier score: 0.2414 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6758 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6758 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 53/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2334 - accuracy: 0.6401 - auc: 0.5000 - cross entropy: 0.6598 - fn: 0.0000e+00 - fp: 79.5385 - loss: 0.6598 - prc: 0.6401 - precision: 0.6401 - recall: 1.0000 - tn: 0.0000e+00 - tp: 138.9231 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6757 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6757 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 54/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2375 - accuracy: 0.6158 - auc: 0.5000 - cross entropy: 0.6680 - fn: 0.0000e+00 - fp: 84.4615 - loss: 0.6680 - prc: 0.6158 - precision: 0.6158 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.0000 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6757 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6757 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 55/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2363 - accuracy: 0.6228 - auc: 0.5000 - cross entropy: 0.6655 - fn: 0.0000e+00 - fp: 82.0769 - loss: 0.6655 - prc: 0.6228 - precision: 0.6228 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.3846 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6757 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6757 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 56/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2351 - accuracy: 0.6292 - auc: 0.5000 - cross entropy: 0.6631 - fn: 0.0000e+00 - fp: 82.0769 - loss: 0.6631 - prc: 0.6292 - precision: 0.6292 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.3846 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6757 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6757 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 57/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2395 - accuracy: 0.6039 - auc: 0.5000 - cross entropy: 0.6719 - fn: 0.0000e+00 - fp: 85.6923 - loss: 0.6719 - prc: 0.6039 - precision: 0.6039 - recall: 1.0000 - tn: 0.0000e+00 - tp: 132.7692 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6757 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6757 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 58/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2363 - accuracy: 0.6217 - auc: 0.5000 - cross entropy: 0.6656 - fn: 0.0000e+00 - fp: 83.6154 - loss: 0.6656 - prc: 0.6217 - precision: 0.6217 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.8462 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 59/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2375 - accuracy: 0.6147 - auc: 0.5000 - cross entropy: 0.6680 - fn: 0.0000e+00 - fp: 85.2308 - loss: 0.6680 - prc: 0.6147 - precision: 0.6147 - recall: 1.0000 - tn: 0.0000e+00 - tp: 133.2308 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 60/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2402 - accuracy: 0.5994 - auc: 0.5000 - cross entropy: 0.6734 - fn: 0.0000e+00 - fp: 83.1538 - loss: 0.6734 - prc: 0.5994 - precision: 0.5994 - recall: 1.0000 - tn: 0.0000e+00 - tp: 135.3077 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 61/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2349 - accuracy: 0.6286 - auc: 0.5000 - cross entropy: 0.6627 - fn: 0.0000e+00 - fp: 82.2308 - loss: 0.6627 - prc: 0.6286 - precision: 0.6286 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.2308 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 62/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2360 - accuracy: 0.6221 - auc: 0.5000 - cross entropy: 0.6650 - fn: 0.0000e+00 - fp: 81.7692 - loss: 0.6650 - prc: 0.6221 - precision: 0.6221 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.6923 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 63/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2386 - accuracy: 0.6078 - auc: 0.5000 - cross entropy: 0.6702 - fn: 0.0000e+00 - fp: 83.9231 - loss: 0.6702 - prc: 0.6078 - precision: 0.6078 - recall: 1.0000 - tn: 0.0000e+00 - tp: 134.5385 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 64/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Brier score: 0.2351 - accuracy: 0.6268 - auc: 0.4770 - cross entropy: 0.6630 - fn: 0.0000e+00 - fp: 82.8462 - loss: 0.6630 - prc: 0.6143 - precision: 0.6268 - recall: 1.0000 - tn: 0.0000e+00 - tp: 135.6154 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 65/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2323 - accuracy: 0.6414 - auc: 0.5000 - cross entropy: 0.6574 - fn: 0.0000e+00 - fp: 81.1538 - loss: 0.6574 - prc: 0.6414 - precision: 0.6414 - recall: 1.0000 - tn: 0.0000e+00 - tp: 137.3077 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 66/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2364 - accuracy: 0.6189 - auc: 0.5000 - cross entropy: 0.6658 - fn: 0.0000e+00 - fp: 82.3846 - loss: 0.6658 - prc: 0.6189 - precision: 0.6189 - recall: 1.0000 - tn: 0.0000e+00 - tp: 136.0769 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 67/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2325 - accuracy: 0.6395 - auc: 0.5000 - cross entropy: 0.6578 - fn: 0.0000e+00 - fp: 80.0769 - loss: 0.6578 - prc: 0.6395 - precision: 0.6395 - recall: 1.0000 - tn: 0.0000e+00 - tp: 138.3846 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 68/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2363 - accuracy: 0.6193 - auc: 0.5000 - cross entropy: 0.6655 - fn: 0.0000e+00 - fp: 82.5385 - loss: 0.6655 - prc: 0.6193 - precision: 0.6193 - recall: 1.0000 - tn: 0.0000e+00 - tp: 135.9231 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 69/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Brier score: 0.2342 - accuracy: 0.6302 - auc: 0.5000 - cross entropy: 0.6612 - fn: 0.0000e+00 - fp: 83.4615 - loss: 0.6612 - prc: 0.6302 - precision: 0.6302 - recall: 1.0000 - tn: 0.0000e+00 - tp: 135.0000 - val_Brier score: 0.2413 - val_accuracy: 0.5934 - val_auc: 0.5000 - val_cross entropy: 0.6756 - val_fn: 0.0000e+00 - val_fp: 37.0000 - val_loss: 0.6756 - val_prc: 0.5934 - val_precision: 0.5934 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 54.0000
# Epoch 69: early stopping
# Restoring model weights from the end of the best epoch: 64.

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Time')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_attn_array = []
attn = model.layers[2]

for x in train_features:
    _, attention_scores = attn(x.reshape(1,-1,1), x.reshape(1,-1,1), return_attention_scores=True) # take one sample
    mean_attn_array.append(attention_scores[0, 0, :, :])

mean_attn_array = np.array(mean_attn_array)
mean_attn = mean_attn_array.mean(axis=0)

# %%
plt.figure(figsize=(10,10))
sb.heatmap(mean_attn, annot=False, cbar=True, square=True, fmt='.2f')
plt.show()

# %%
mean_attn.sum(axis=0)
# Out:
# array([1.0048795 , 0.9857804 , 1.0068898 , 1.0069373 , 0.99663454,
#        1.0154456 , 1.0184869 , 1.0173974 , 0.99481124, 0.98590344,
#        1.0030639 , 0.9760068 , 1.0040241 , 1.000955  , 0.9768576 ,
#        1.0032284 , 0.993861  , 1.0049958 , 0.9784756 , 0.9900349 ,
#        1.0075777 , 0.98772943, 1.0097495 , 1.0086454 , 0.9942519 ,
#        1.0104882 , 1.0122834 , 1.0146084 , 0.99265563, 0.9973408 ],
#       dtype=float32)

# %%
cols = df['feature_names']

# sort cols by max attention
att_sum = mean_attn.sum(axis=0)
cols[att_sum.argsort()[::-1]]
# Out:
# array(['mean concavity', 'mean concave points', 'mean compactness',
#        'worst concave points', 'worst concavity', 'worst compactness',
#        'worst perimeter', 'worst area', 'worst radius', 'mean area',
#        'mean perimeter', 'concave points error', 'mean radius',
#        'perimeter error', 'compactness error', 'radius error',
#        'area error', 'worst fractal dimension', 'mean smoothness',
#        'mean symmetry', 'worst smoothness', 'concavity error',
#        'worst symmetry', 'fractal dimension error', 'worst texture',
#        'mean fractal dimension', 'mean texture', 'symmetry error',
#        'smoothness error', 'texture error'], dtype='<U23')

# %%
# Lasso Regression Analysis
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(train_features)

# Fit Lasso regression
lasso = Lasso(alpha=0.01)  # Small alpha for less aggressive regularization
lasso.fit(X_scaled, train_labels.ravel())

# Get feature importance (absolute coefficients)
lasso_importance = np.abs(lasso.coef_)

# Sort features by importance
lasso_feature_importance = pd.DataFrame({
    'feature': cols,
    'importance': lasso_importance
}).sort_values('importance', ascending=False)

print("\nLasso Regression Feature Importance:")
print(lasso_feature_importance)

# Compare with attention-based importance
att_sum = mean_attn.sum(axis=0)
attention_feature_importance = pd.DataFrame({
    'feature': cols,
    'importance': att_sum
}).sort_values('importance', ascending=False)

print("\nAttention-based Feature Importance:")
print(attention_feature_importance)

# Plot comparison
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.bar(range(len(lasso_importance)), lasso_importance)
plt.title('Lasso Regression Feature Importance')
plt.xticks(range(len(cols)), cols, rotation=45, ha='right')
plt.tight_layout()

plt.subplot(1, 2, 2)
plt.bar(range(len(att_sum)), att_sum)
plt.title('Attention-based Feature Importance')
plt.xticks(range(len(cols)), cols, rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Lasso Regression Feature Importance:
#                     feature  importance
# 20             worst radius    0.141050
# 27     worst concave points    0.101255
# 1              mean texture    0.068755
# 26          worst concavity    0.058851
# 24         worst smoothness    0.053894
# 10             radius error    0.045886
# 28           worst symmetry    0.032952
# 9    mean fractal dimension    0.029699
# 7       mean concave points    0.020512
# 0               mean radius    0.012787
# 15        compactness error    0.004760
# 21            worst texture    0.000598
# 5          mean compactness    0.000000
# 2            mean perimeter    0.000000
# 13               area error    0.000000
# 12          perimeter error    0.000000
# 11            texture error    0.000000
# 8             mean symmetry    0.000000
# 6            mean concavity    0.000000
# 3                 mean area    0.000000
# 4           mean smoothness    0.000000
# 14         smoothness error    0.000000
# 18           symmetry error    0.000000
# 19  fractal dimension error    0.000000
# 16          concavity error    0.000000
# 17     concave points error    0.000000
# 25        worst compactness    0.000000
# 23               worst area    0.000000
# 22          worst perimeter    0.000000
# 29  worst fractal dimension    0.000000
#
# Attention-based Feature Importance:
#                     feature  importance
# 6            mean concavity    1.018487
# 7       mean concave points    1.017397
# 5          mean compactness    1.015446
# 27     worst concave points    1.014608
# 26          worst concavity    1.012283
# 25        worst compactness    1.010488
# 22          worst perimeter    1.009750
# 23               worst area    1.008645
# 20             worst radius    1.007578
# 3                 mean area    1.006937
# 2            mean perimeter    1.006890
# 17     concave points error    1.004996
# 0               mean radius    1.004879
# 12          perimeter error    1.004024
# 15        compactness error    1.003228
# 10             radius error    1.003064
# 13               area error    1.000955
# 29  worst fractal dimension    0.997341
# 4           mean smoothness    0.996635
# 8             mean symmetry    0.994811
# 24         worst smoothness    0.994252
# 16          concavity error    0.993861
# 28           worst symmetry    0.992656
# 19  fractal dimension error    0.990035
# 21            worst texture    0.987729
# 9    mean fractal dimension    0.985903
# 1              mean texture    0.985780
# 18           symmetry error    0.978476
# 14         smoothness error    0.976858
# 11            texture error    0.976007
